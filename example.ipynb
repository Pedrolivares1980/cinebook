# %%
import requests

apiKey='a461382033e324b0ce66c1ed513d3d38'
tmdbId=120

# %%
url=f"https://api.themoviedb.org/3/movie/{tmdbId}?api_key={apiKey}&append_to_response=credits,videos"

# %%
response = requests.get(url)

# %%
response.json()
# Out:
# {'adult': False,
#  'backdrop_path': '/x2RS3uTcsJJ9IfjNPcgDmukoEcQ.jpg',
#  'belongs_to_collection': {'id': 119,
#   'name': 'The Lord of the Rings Collection',
#   'poster_path': '/oENY593nKRVL2PnxXsMtlh8izb4.jpg',
#   'backdrop_path': '/bccR2CGTWVVSZAG0yqmy3DIvhTX.jpg'},
#  'budget': 93000000,
#  'genres': [{'id': 12, 'name': 'Adventure'},
#   {'id': 14, 'name': 'Fantasy'},
#   {'id': 28, 'name': 'Action'}],
#  'homepage': 'http://www.lordoftherings.net/',
#  'id': 120,
#  'imdb_id': 'tt0120737',
#  'original_language': 'en',
#  'original_title': 'The Lord of the Rings: The Fellowship of the Ring',
#  'overview': 'Young hobbit Frodo Baggins, after inheriting a mysterious ring from his uncle Bilbo, must leave his home in order to keep it from falling into the hands of its evil creator. Along the way, a fellowship is formed to protect the ringbearer and make sure that the ring arrives at its final destination: Mt. Doom, the only place where it can be destroyed.',
# ...

# %%
data = response.json()
data['credits']['cast']
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 28, 'name': 'Action'}]

# %%
data['credits']['crew']
# Out:
# [{'adult': False,
#   'gender': 2,
#   'id': 123,
#   'known_for_department': 'Production',
#   'name': 'Barrie M. Osborne',
#   'original_name': 'Barrie M. Osborne',
#   'popularity': 7.957,
#   'profile_path': '/xWtXYk6M5NFroddcQDviLlxOnkU.jpg',
#   'credit_id': '52fe421ac3a36847f80043fb',
#   'department': 'Production',
#   'job': 'Producer'},
#  {'adult': False,
#   'gender': 2,
#   'id': 117,
#   'known_for_department': 'Sound',
#   'name': 'Howard Shore',
#   'original_name': 'Howard Shore',
#   'popularity': 10.064,
#   'profile_path': '/nJ606tXnL8vDVHi7qavrV292ljt.jpg',
#   'credit_id': '52fe421ac3a36847f8004437',
#   'department': 'Sound',
#   'job': 'Original Music Composer'},
#  {'adult': False,
#   'gender': 2,
#   'id': 900,
#   'known_for_department': 'Sound',
#   'name': 'Christopher Boyes',
#   'original_name': 'Christopher Boyes',
#   'popularity': 11.796,
#   'profile_path': None,
#   'credit_id': '5af36fff0e0a263950002897',
#   'department': 'Sound',
# ...

# %%
data['genres']
